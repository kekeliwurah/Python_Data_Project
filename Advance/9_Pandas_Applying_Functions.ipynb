# %%
#importing libraries
from datasets import load_dataset
import pandas as pd
import matplotlib.pyplot as 
import ast

# loading data
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()
 
# data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_salary = df[pd.notna(df['salary_year_avg'])].copy()

# %%
def projected_salary(salary):
    return salary * 1.03

df_salary['salary_year_inflated'] = df['salary_year_avg'].apply(projected_salary)

df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(lambda salary: salary *1.03)

df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
import ast
ast.literal_eval(df['job_skills'][1])
# Out:
# ['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']

# %%
def clean_list(skill_list):
     if pd.notna(skill_list): 
            return ast.literal_eval(skill_list)

# %%
df['job_skills'] = df['job_skills'].apply(clean_list)

# %%
type(df['job_skills'][1])
# Out:
# NoneType

# %%
df['job_skills'] = df['job_skills'].apply(lambda skill_list: ast.literal_eval(skill_list) if pd.notna(skill_list) else skill_list)

# %% [markdown]
# ##Calculate projected salary next year
# #senior roles assume 5%
# #other roles assume 3%

# %%
df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(lambda salary: salary *1.03)

df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
# list

# %%
def projected_salary(row):
    if "Senior" in row['job_title_short']:
        return 1.05 * row['salary_year_avg']
    else:
        return 1.03 * row['salary_year_avg']

# %%
df_salary['salary_year_inflated'] = df_salary.apply(projected_salary, axis= 1)

# %%
df_salary.sample(5)
# Out:
#              job_title_short  \
# 654630  Senior Data Engineer
# 226510          Data Analyst
# 487709         Data Engineer
# 152957          Data Analyst
# 207368        Data Scientist
#
#                                                 job_title    job_location  \
# 654630      Senior Staff Software Engineer, Data Platform     Seattle, WA
# 226510                       Data Scientist/ Data Analyst    New York, NY
# 487709                                   Data Engineer, 2    New York, NY
# 152957  Project Manager - Data Analyst. Job in Carroll...  Carrollton, TX
# 207368                                 Sr. Data Scientist     Raritan, NJ
#
#                          job_via job_schedule_type  job_work_from_home  \
# 654630           via Ai-Jobs.net         Full-time               False
# 226510               via Ladders         Full-time               False
# 487709               via Ladders         Full-time               False
# 152957  via My Valley Jobs Today         Full-time               False
# 207368                via Indeed         Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 654630    New York, United States 2023-03-15 10:05:33                  False
# 226510    New York, United States 2023-04-23 06:59:58                  False
# 487709  California, United States 2023-08-23 11:07:09                   True
# 152957       Texas, United States 2023-01-25 08:01:43                  False
# 207368    New York, United States 2023-07-25 22:03:06                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 654630                  True  United States        year         245000.0
# 226510                  True  United States        year         150000.0
# 487709                  True  United States        year         125000.0
# 152957                 False  United States        year         146100.0
# 207368                 False  United States        year         155000.0
#
#         salary_hour_avg                 company_name  \
# 654630              NaN                  Outreach.io
# 226510              NaN  Tower Research Capital, LLC
# 487709              NaN         Meredith Corporation
# 152957              NaN                         Citi
# 207368              NaN                   Apptad Inc
#
#                                                job_skills  \
# 654630  ['python', 'ruby', 'ruby', 'aws', 'spark', 'ku...
# 226510                ['c#', 'c++', 'java', 'sql', 'gcp']
# 487709          ['python', 'sql', 'gcp', 'aws', 'looker']
# 152957      ['excel', 'powerpoint', 'confluence', 'jira']
# 207368                         ['python', 'java', 'flow']
#
#                                           job_type_skills  \
# 654630  {'cloud': ['aws'], 'libraries': ['spark'], 'ot...
# 226510  {'cloud': ['gcp'], 'programming': ['c#', 'c++'...
# 487709  {'analyst_tools': ['looker'], 'cloud': ['gcp',...
# 152957  {'analyst_tools': ['excel', 'powerpoint'], 'as...
# 207368  {'other': ['flow'], 'programming': ['python', ...
#
#         salary_year_inflated
# 654630              257250.0
# 226510              154500.0
# 487709              128750.0
# 152957              150483.0
# 207368              159650.0
